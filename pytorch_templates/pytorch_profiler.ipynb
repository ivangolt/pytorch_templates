# %%
import torch
import torchvision.models as models
from torch.profiler import profile, record_function, ProfilerActivity

# %%
model = models.resnet18()
inputs = torch.randn(5, 3, 224, 224)

# %%
inputs
# Out:
# tensor([[[[-1.2130e+00, -2.1366e-02,  1.8520e+00,  ..., -1.1397e+00,
#            -1.2264e+00,  1.1271e+00],
#           [-1.2930e-01, -8.4158e-01,  2.2435e-03,  ..., -1.3814e-01,
#             1.3570e+00,  2.2503e+00],
#           [ 1.1455e+00,  1.0473e+00, -1.3119e+00,  ..., -1.2527e+00,
#            -2.8997e-01, -2.6788e-02],
#           ...,
#           [-1.1192e-01, -1.0185e+00,  1.2440e-01,  ..., -6.0027e-01,
#            -9.8627e-01,  4.0893e-01],
#           [ 1.5661e-01,  2.8437e+00, -2.0038e+00,  ...,  1.0942e+00,
#             7.8916e-01, -1.6268e+00],
#           [-3.3045e-01,  1.5281e+00, -6.1346e-01,  ...,  6.4249e-01,
#            -1.1717e-02,  1.1233e+00]],
#
#          [[ 8.3485e-01,  5.0955e-02,  9.6315e-01,  ...,  1.1820e-01,
#            -1.8596e+00, -1.6322e+00],
#           [ 1.4537e+00,  6.1535e-02,  1.4116e+00,  ...,  5.9929e-01,
#             3.9586e-02,  8.5000e-01],
#           [ 8.8343e-01,  1.0610e-01,  3.1133e-01,  ..., -7.5147e-01,
#             9.9704e-02, -1.4362e+00],
#           ...,
#           [ 2.3436e-01,  5.4048e-01, -1.5053e+00,  ..., -1.1118e+00,
#             1.6720e-01,  1.3114e+00],
#           [ 6.3932e-01, -2.5316e-01,  1.5859e+00,  ...,  2.5112e-01,
#             6.2459e-01,  3.3985e-01],
#           [ 8.9398e-01, -1.2785e+00, -7.0991e-01,  ..., -1.4410e+00,
#             6.9002e-01,  5.3129e-01]],
#
#          [[ 8.0827e-01,  2.7379e-01,  1.5767e-01,  ..., -9.9770e-01,
#            -6.3450e-01,  5.6053e-01],
#           [-2.0599e+00,  2.1858e-01, -7.9906e-02,  ..., -7.2166e-01,
#            -1.7930e-03,  2.3550e-01],
#           [-3.3649e-01, -1.0248e+00, -3.1536e-01,  ...,  5.8162e-01,
#             2.6542e+00, -1.4672e+00],
#           ...,
#           [ 2.0200e+00,  6.5283e-02, -2.3009e-01,  ...,  8.1348e-01,
#             8.3239e-01,  6.6362e-01],
#           [-6.3657e-01,  2.4207e-02,  2.0257e-01,  ...,  5.2770e-02,
#             4.0846e-01,  1.2364e+00],
#           [ 1.2058e+00, -1.3892e+00, -1.1284e+00,  ...,  8.6351e-01,
#            -1.4756e+00, -4.3846e-01]]],
#
#
#         [[[-3.7293e-02,  3.6778e-01,  2.7683e-01,  ...,  1.2180e+00,
#            -1.3151e-01, -3.8348e-01],
#           [-1.9992e+00, -9.9504e-01, -3.8731e-01,  ...,  1.2267e+00,
#            -5.2897e-01, -4.6383e-01],
#           [ 1.4647e+00,  1.6468e+00, -1.4174e+00,  ...,  6.6212e-01,
#             1.5444e+00, -2.2288e-01],
#           ...,
#           [ 5.6322e-01, -6.5951e-01, -1.6032e+00,  ..., -4.6630e-01,
#            -1.4372e+00,  1.0026e+00],
#           [-3.4677e-01, -8.3806e-01, -4.9338e-02,  ..., -1.0465e+00,
#             1.2006e+00,  1.8597e+00],
#           [ 9.9208e-01,  5.5712e-01, -6.3149e-01,  ...,  4.5926e-01,
#             8.1936e-01,  2.1263e-01]],
#
#          [[ 9.7628e-01,  9.3352e-01, -1.5447e+00,  ...,  4.4281e-01,
#             7.2026e-01, -5.1288e-01],
#           [-8.0875e-01,  8.0306e-01, -1.4587e+00,  ...,  4.6420e-01,
#            -8.1611e-01,  4.7073e-01],
#           [ 8.4925e-03,  5.2163e-01, -1.2811e+00,  ..., -1.2617e-01,
#            -8.1454e-01, -4.9831e-01],
#           ...,
#           [-4.7011e-01, -9.7255e-02,  2.4179e+00,  ..., -8.8572e-01,
#            -8.7164e-01,  9.2968e-01],
#           [ 6.7177e-01,  1.0536e+00,  1.1406e+00,  ..., -4.6692e-01,
#             1.2367e+00, -3.6119e-01],
#           [ 1.6417e-02, -7.7165e-01, -1.0907e+00,  ..., -1.0900e+00,
#            -1.6900e+00, -4.1131e-01]],
#
#          [[ 2.9710e+00, -5.6330e-01, -6.5733e-01,  ...,  6.0753e-01,
#             2.0894e+00,  2.8052e-01],
#           [-3.9245e-01, -9.0751e-01, -1.3209e+00,  ...,  7.7923e-01,
#             2.3978e-01,  2.0781e+00],
#           [-1.8366e-01, -1.3592e-01, -2.2912e-01,  ..., -1.6611e+00,
#             9.0671e-01,  4.8733e-01],
#           ...,
#           [ 9.3153e-01, -1.0799e+00,  1.2441e+00,  ...,  1.8250e-01,
#             8.0544e-01, -3.0225e-01],
#           [ 1.2517e+00,  7.2789e-01, -2.7522e-01,  ...,  1.8900e-01,
#             1.3628e+00, -6.4779e-01],
#           [-6.6070e-01, -1.0041e+00, -4.8583e-01,  ..., -5.3548e-01,
#            -3.4608e-01, -3.0556e-02]]],
#
#
#         [[[-2.1245e+00, -1.2863e+00, -1.2948e-01,  ...,  1.0524e-01,
#             2.8772e-01,  6.6800e-01],
#           [ 2.3343e-02, -1.4881e+00, -1.4491e+00,  ..., -1.0387e-01,
#             1.6656e-02,  5.0471e-01],
#           [ 1.2859e+00, -5.6766e-02,  3.1939e-01,  ..., -4.0682e-01,
#             1.1830e+00,  1.1132e+00],
#           ...,
#           [-8.6623e-01, -2.8327e-01, -1.2817e+00,  ..., -8.2883e-01,
#            -4.5291e-01,  8.9577e-02],
#           [-1.9137e+00,  1.1660e+00, -2.5865e+00,  ...,  1.1419e-01,
#            -4.7342e-01,  2.3012e-01],
#           [ 1.0269e-01,  1.0757e+00,  1.2199e+00,  ...,  1.2200e+00,
#             2.1168e+00, -2.3781e+00]],
#
#          [[-9.0549e-01, -1.1604e+00, -1.9652e+00,  ...,  2.0478e-01,
#            -5.6891e-01,  2.8173e-01],
#           [-2.5425e-01,  2.0910e+00,  1.0567e+00,  ...,  8.3428e-01,
#            -1.4423e-01, -4.2572e-01],
#           [-4.2285e-01,  7.2592e-02,  1.1696e+00,  ..., -2.5232e-02,
#             1.7283e+00,  3.1818e-01],
#           ...,
#           [ 4.9230e-01, -2.4108e+00, -2.7295e-01,  ...,  8.8881e-01,
#            -2.3792e-01, -1.4608e+00],
#           [-5.8538e-02, -1.0283e+00, -2.1263e+00,  ...,  9.1350e-01,
#             5.2836e-01, -1.3353e+00],
#           [ 8.8617e-01, -1.9244e+00, -2.3190e-01,  ...,  3.8912e-02,
#            -6.9699e-01,  2.2659e+00]],
#
#          [[ 1.4273e+00,  8.8599e-01, -2.0052e-02,  ...,  5.4648e-01,
#            -4.0572e-01,  1.4716e-01],
#           [ 1.1626e+00, -4.0931e-01,  5.0413e-02,  ...,  1.4381e+00,
#            -4.2361e-01,  1.2208e+00],
#           [ 9.6604e-01,  7.8777e-01,  3.0929e-01,  ..., -3.1505e-01,
#             2.0607e+00, -7.3116e-01],
#           ...,
#           [ 1.1706e+00,  3.5874e-01,  1.0947e+00,  ...,  8.8144e-01,
#            -5.5250e-01, -1.9962e-01],
#           [-2.8062e-01,  4.7299e-02,  1.2551e+00,  ...,  1.9132e+00,
#             1.4813e+00, -2.2684e+00],
#           [ 6.9134e-01, -6.0194e-01, -2.9324e-01,  ..., -2.6017e-01,
#             1.6610e+00,  1.1459e-02]]],
#
#
#         [[[-6.5202e-01, -2.2574e+00,  5.0955e-01,  ...,  1.2989e+00,
#            -7.3135e-01,  1.7837e+00],
#           [ 8.0253e-01,  3.7531e-01, -9.9487e-02,  ...,  7.2001e-01,
#             2.7362e-01,  4.5315e-01],
#           [-1.8486e-01, -3.8878e-01, -3.0360e-01,  ...,  3.4742e+00,
#            -2.2778e-01,  3.3042e-01],
#           ...,
#           [ 1.2765e+00,  3.9469e-01,  3.9205e-01,  ...,  8.6097e-01,
#            -1.1549e+00, -2.6723e+00],
#           [-2.0077e+00, -1.3442e+00,  3.5709e-01,  ..., -1.7146e+00,
#            -1.0503e+00,  3.1751e-01],
#           [ 1.0208e+00, -2.1112e+00,  6.0310e-01,  ..., -3.0881e-01,
#            -1.3727e+00,  7.8872e-01]],
#
#          [[-4.9834e-01,  4.7852e-01,  6.5949e-01,  ..., -4.2023e-01,
#            -6.7351e-01,  3.4148e-01],
#           [-9.1155e-01, -1.1322e-01, -2.8087e-01,  ...,  6.3483e-01,
#            -7.6724e-01, -3.5544e-01],
#           [-6.1816e-01, -8.8576e-01, -7.0722e-02,  ...,  7.3785e-01,
#            -3.1062e+00,  6.7813e-01],
#           ...,
#           [ 6.7585e-01,  4.6433e-01, -3.1697e-01,  ..., -1.3296e-01,
#            -4.2626e-01, -1.9929e+00],
#           [ 3.0061e-01,  1.1541e+00,  2.5467e-01,  ...,  2.8327e-01,
#             6.5731e-01, -5.8610e-01],
#           [ 2.3170e+00,  8.3732e-01,  3.0573e-01,  ..., -4.3699e-01,
#            -4.4231e-01, -1.7856e-01]],
#
#          [[ 2.0174e+00, -9.9841e-02,  1.7272e+00,  ..., -1.5925e+00,
#            -1.1157e+00,  9.3009e-01],
#           [-1.0621e+00, -6.4401e-01,  1.5321e+00,  ..., -1.9286e+00,
#            -1.0176e+00,  2.2049e-01],
#           [ 5.5219e-01, -8.6984e-01,  2.6922e+00,  ..., -2.6438e-01,
#             8.6972e-01,  1.6444e-01],
#           ...,
#           [-1.6958e-01, -3.8521e-01,  2.7482e+00,  ...,  6.9440e-01,
#             9.9645e-01, -5.7328e-01],
#           [-3.2914e-01, -8.9318e-01,  1.4307e+00,  ..., -4.0452e-01,
#            -7.3800e-01, -4.6425e-01],
#           [-4.4204e-01,  8.3155e-01, -7.8268e-01,  ..., -9.1279e-03,
#            -6.2732e-01,  1.2015e+00]]],
#
#
#         [[[ 1.3446e+00,  2.0303e-01,  8.5897e-01,  ..., -1.0252e+00,
#            -1.0016e+00,  1.3805e+00],
#           [-2.2380e+00, -5.0914e-01, -7.7522e-01,  ..., -3.9536e-01,
#            -1.8248e+00, -1.6314e-01],
#           [ 9.7513e-01,  3.4411e-01,  1.5478e+00,  ..., -4.6487e-01,
#             6.3249e-02,  7.4885e-01],
#           ...,
#           [ 5.4247e-01, -5.0936e-01,  7.3482e-01,  ..., -4.5491e-01,
#             6.1212e-01,  2.5639e-01],
#           [-1.6807e-01, -3.3429e-01, -2.4015e-01,  ..., -1.8993e+00,
#             1.8831e+00,  4.3332e-01],
#           [-5.7450e-01,  3.7205e-01,  2.0379e+00,  ...,  5.7458e-03,
#            -1.0315e+00, -1.5182e+00]],
#
#          [[ 1.2969e+00,  7.2701e-01, -2.1236e-01,  ..., -2.8465e-01,
#             2.4098e-01,  4.5397e-01],
#           [ 2.5411e-01,  1.1435e+00, -1.4963e-01,  ...,  1.6047e+00,
#             4.7099e-01,  1.5686e+00],
#           [ 1.8882e-01, -1.0120e+00, -9.9289e-01,  ...,  3.1428e+00,
#            -1.0212e-01, -1.8144e+00],
#           ...,
#           [ 6.1636e-02, -8.1902e-01, -6.5460e-01,  ...,  1.1024e+00,
#             6.6264e-01, -1.1446e+00],
#           [ 7.6852e-01,  2.3043e+00,  6.4144e-01,  ..., -2.0157e+00,
#            -3.4050e-01,  9.4477e-01],
#           [ 2.2274e-01, -7.5301e-01, -1.6677e-01,  ...,  3.2096e-01,
#            -3.6482e-01, -8.5038e-01]],
#
#          [[-6.2152e-01,  2.0172e-01, -9.7220e-01,  ...,  2.5077e+00,
#            -3.5636e-01, -2.0276e+00],
#           [ 3.7393e-02,  2.0114e+00,  1.3781e+00,  ...,  5.9462e-01,
#             1.8101e-01, -5.7138e-01],
#           [-1.5136e+00, -3.6842e-01, -1.0796e+00,  ...,  3.5455e-01,
#             1.9075e+00,  2.6492e-01],
#           ...,
#           [-9.7443e-01, -8.6084e-01, -7.9579e-01,  ..., -5.6157e-01,
#            -2.1531e-01,  2.2222e-02],
#           [ 1.2052e+00,  1.9951e+00, -1.3631e+00,  ..., -1.5930e+00,
#            -1.9464e+00, -7.9242e-01],
#           [ 6.8527e-01,  6.1714e-02, -1.5629e+00,  ...,  7.6629e-01,
#            -7.2676e-01, -3.6703e-01]]]])

# %% [markdown]
# # Using profiler to analyze execution time

# %%
with profile(activities=[ProfilerActivity.CPU], record_shapes=True) as prof:
    with record_function("model_inference"):
        model(inputs)

# %%
print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))
# Out:
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                   model_inference         5.05%      32.434ms       100.00%     642.076ms     642.076ms             1
#                      aten::conv2d         0.31%       2.021ms        59.09%     379.415ms      18.971ms            20
#                 aten::convolution         0.95%       6.104ms        58.78%     377.394ms      18.870ms            20
#                aten::_convolution         0.55%       3.544ms        57.83%     371.290ms      18.564ms            20
#          aten::mkldnn_convolution        56.94%     365.566ms        57.27%     367.746ms      18.387ms            20
#                  aten::batch_norm         0.25%       1.586ms        12.31%      79.046ms       3.952ms            20
#      aten::_batch_norm_impl_index         0.29%       1.875ms        12.06%      77.460ms       3.873ms            20
#           aten::native_batch_norm        11.58%      74.358ms        11.75%      75.419ms       3.771ms            20
#                  aten::max_pool2d         0.16%       1.000ms        10.27%      65.921ms      65.921ms             1
#     aten::max_pool2d_with_indices        10.11%      64.921ms        10.11%      64.921ms      64.921ms             1
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 642.076ms

# %%
print(prof.key_averages(group_by_input_shape=True).table(sort_by="cpu_time_total", row_limit=10))
# Out:
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  --------------------------------------------------------------------------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls                                                                      Input Shapes
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  --------------------------------------------------------------------------------
#                   model_inference         5.05%      32.434ms       100.00%     642.076ms     642.076ms             1                                                                                []
#                      aten::conv2d         0.23%       1.504ms        16.39%     105.227ms     105.227ms             1                             [[5, 3, 224, 224], [64, 3, 7, 7], [], [], [], [], []]
#                 aten::convolution         0.74%       4.742ms        16.15%     103.723ms     103.723ms             1                     [[5, 3, 224, 224], [64, 3, 7, 7], [], [], [], [], [], [], []]
#                aten::_convolution         0.42%       2.700ms        15.42%      98.981ms      98.981ms             1     [[5, 3, 224, 224], [64, 3, 7, 7], [], [], [], [], [], [], [], [], [], [], []]
#          aten::mkldnn_convolution        14.84%      95.288ms        15.00%      96.281ms      96.281ms             1                             [[5, 3, 224, 224], [64, 3, 7, 7], [], [], [], [], []]
#                      aten::conv2d         0.02%     100.000us        10.72%      68.852ms      17.213ms             4                             [[5, 64, 56, 56], [64, 64, 3, 3], [], [], [], [], []]
#                 aten::convolution         0.05%     300.000us        10.71%      68.752ms      17.188ms             4                     [[5, 64, 56, 56], [64, 64, 3, 3], [], [], [], [], [], [], []]
#                aten::_convolution         0.04%     233.000us        10.66%      68.452ms      17.113ms             4     [[5, 64, 56, 56], [64, 64, 3, 3], [], [], [], [], [], [], [], [], [], [], []]
#          aten::mkldnn_convolution        10.59%      67.977ms        10.62%      68.219ms      17.055ms             4                             [[5, 64, 56, 56], [64, 64, 3, 3], [], [], [], [], []]
#                  aten::max_pool2d         0.16%       1.000ms        10.27%      65.921ms      65.921ms             1                                           [[5, 64, 112, 112], [], [], [], [], []]
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  --------------------------------------------------------------------------------
# Self CPU time total: 642.076ms

# %%
model = models.resnet18().cuda()
inputs = torch.randn(1, 3, 224, 224).cuda()

with profile(activities=[
        ProfilerActivity.CPU, ProfilerActivity.CUDA], record_shapes=True) as prof:
    with record_function("model_inference"):
        model(inputs)

print(prof.key_averages().table(sort_by="cuda_time_total", row_limit=10))
# Out:
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                   model_inference         0.67%      14.477ms       100.00%        2.160s        2.160s     195.000us         0.01%        1.577s        1.577s             1
#                      aten::conv2d         0.03%     655.000us        88.21%        1.905s      95.260ms      66.000us         0.00%        1.349s      67.456ms            20
#                 aten::convolution         0.06%       1.362ms        88.18%        1.905s      95.228ms      68.000us         0.00%        1.349s      67.453ms            20
#                aten::_convolution         0.12%       2.673ms        88.12%        1.903s      95.159ms      82.000us         0.01%        1.349s      67.449ms            20
#           aten::cudnn_convolution        87.99%        1.901s        87.99%        1.901s      95.026ms        1.349s        85.56%        1.349s      67.445ms            20
#                        aten::add_         2.70%      58.215ms         2.70%      58.215ms       2.079ms      75.076ms         4.76%      75.076ms       2.681ms            28
#                  aten::max_pool2d         0.00%      37.000us         0.30%       6.397ms       6.397ms       3.000us         0.00%      51.567ms      51.567ms             1
#     aten::max_pool2d_with_indices         0.29%       6.360ms         0.29%       6.360ms       6.360ms      51.564ms         3.27%      51.564ms      51.564ms             1
#                  aten::batch_norm         0.02%     480.000us         3.51%      75.853ms       3.793ms      68.000us         0.00%      40.917ms       2.046ms            20
#      aten::_batch_norm_impl_index         0.20%       4.415ms         3.49%      75.373ms       3.769ms      70.000us         0.00%      40.849ms       2.042ms            20
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 2.160s
# Self CUDA time total: 1.577s

# %% [markdown]
# # Using profiler to analyze memory consumption

# %%
model = models.resnet18()
inputs = torch.randn(5, 3, 224, 224)

with profile(activities=[ProfilerActivity.CPU],
        profile_memory=True, record_shapes=True) as prof:
    model(inputs)

print(prof.key_averages().table(sort_by="self_cpu_memory_usage", row_limit=10))
print(prof.key_averages().table(sort_by="cpu_memory_usage", row_limit=10))
# Out:
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                       aten::empty         0.36%       2.005ms         0.36%       2.005ms      10.025us      94.86 Mb      94.86 Mb           200
#     aten::max_pool2d_with_indices        19.11%     106.389ms        19.11%     106.389ms     106.389ms      11.48 Mb      11.48 Mb             1
#                       aten::addmm         0.11%     591.000us         0.12%     661.000us     661.000us      19.53 Kb      19.53 Kb             1
#                        aten::mean         0.02%      98.000us         0.11%     591.000us     591.000us      10.00 Kb      10.00 Kb             1
#               aten::empty_strided         0.00%      11.000us         0.00%      11.000us      11.000us           4 b           4 b             1
#                      aten::conv2d         0.09%     500.000us        63.50%     353.531ms      17.677ms      47.37 Mb           0 b            20
#                 aten::convolution         0.30%       1.646ms        63.41%     353.031ms      17.652ms      47.37 Mb           0 b            20
#                aten::_convolution         0.19%       1.058ms        63.11%     351.385ms      17.569ms      47.37 Mb           0 b            20
#          aten::mkldnn_convolution        62.68%     348.953ms        62.92%     350.327ms      17.516ms      47.37 Mb           0 b            20
#                 aten::as_strided_         0.08%     450.000us         0.08%     450.000us      22.500us           0 b           0 b            20
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 556.751ms
#
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                       aten::empty         0.36%       2.005ms         0.36%       2.005ms      10.025us      94.86 Mb      94.86 Mb           200
#                  aten::batch_norm         0.06%     326.000us        13.98%      77.847ms       3.892ms      47.41 Mb           0 b            20
#      aten::_batch_norm_impl_index         0.12%     663.000us        13.92%      77.521ms       3.876ms      47.41 Mb           0 b            20
#           aten::native_batch_norm        13.55%      75.423ms        13.78%      76.732ms       3.837ms      47.41 Mb     -75.00 Kb            20
#                      aten::conv2d         0.09%     500.000us        63.50%     353.531ms      17.677ms      47.37 Mb           0 b            20
#                 aten::convolution         0.30%       1.646ms        63.41%     353.031ms      17.652ms      47.37 Mb           0 b            20
#                aten::_convolution         0.19%       1.058ms        63.11%     351.385ms      17.569ms      47.37 Mb           0 b            20
#          aten::mkldnn_convolution        62.68%     348.953ms        62.92%     350.327ms      17.516ms      47.37 Mb           0 b            20
#                  aten::empty_like         0.05%     255.000us         0.11%     597.000us      29.850us      47.37 Mb           0 b            20
#                  aten::max_pool2d         0.01%      28.000us        19.11%     106.417ms     106.417ms      11.48 Mb           0 b             1
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 556.751ms

# %% [markdown]
# # Using tracing functionality

# %%
model = models.resnet18().cuda()
inputs = torch.randn(1, 3, 224, 224).cuda()

with profile(activities=[ProfilerActivity.CPU, ProfilerActivity.CUDA]) as prof:
    model(inputs)

prof.export_chrome_trace("trace.json")

# %% [markdown]
# # Examining stack traces

# %%
with profile(
    activities=[ProfilerActivity.CPU, ProfilerActivity.CUDA],
    with_stack=True,
) as prof:
    model(inputs)

# Print aggregated stats
print(prof.key_averages(group_by_stack_n=5).table(sort_by="self_cuda_time_total", row_limit=2))
# Out:
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#           aten::cudnn_convolution         3.42%      28.724ms         3.42%      28.724ms       1.436ms       3.093ms        60.77%       3.093ms     154.650us            20
#            aten::cudnn_batch_norm        94.53%     793.439ms        94.68%     794.623ms      39.731ms     889.000us        17.47%       1.162ms      58.100us            20
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 839.313ms
# Self CUDA time total: 5.090ms
